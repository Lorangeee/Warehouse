# %%
import numpy as np
def sigmoid(z):
    '''
    argument: returns the sigmoid activation result
    
    return: A ---- the activation after sigmoid function,(layers_dims[l],1)
    
    z ---- the linear forward result, (layers_dims[l],1);
    '''
    
    a = 1 / ( 1 + np.exp( -1 * z ) )
    
    return a
